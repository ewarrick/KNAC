# %%
from lightkurve import TessTargetPixelFile

# %%
tpf = TessTargetPixelFile("https://mast.stsci.edu/tesscut/api/v0.1/astrocut?ra=83.9307420670716&dec=-6.37211209521442&y=10&x=10&units=px&sector=6")

# %%
tpf.plot()
