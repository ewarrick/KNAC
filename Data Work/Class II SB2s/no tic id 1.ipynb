# %%
from lightkurve import TessTargetPixelFile

# %%
tpf=TessTargetPixelFile("https://mast.stsci.edu/tesscut/api/v0.1/astrocut?ra=84.311081&dec=-1.030694&y=55&x=55&units=px&sector=6")

# %%
tpf.plot()
