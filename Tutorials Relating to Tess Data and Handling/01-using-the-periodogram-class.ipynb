# %% [markdown]
# # What is the Periodogram class?

# %% [markdown]
# *lightkurve* has a class specifically for dealing with periodograms of time series data. This can be useful for finding the periods of variable stars. Below is a quick example of how to find the period of an eclipsing binary star using *lightkurve*.
#
# Firstly lets grab a light curve file from mast. We'll use KIC 10030943, which is an eclipsing binary observed by the original Kepler mission. We're just going to use one quarter for this demo.

# %%
# Obtain the data
from lightkurve import search_lightcurvefile
lc = search_lightcurvefile('10264202', quarter=10).download().PDCSAP_FLUX.remove_nans()

# %% [markdown]
# Let's plot the light curve to see what we're working with.

# %%
lc.scatter();

# %% [markdown]
# This light curve looks like it has some structure in it! Let's use the periodogram class to find the rotation period. You can create a periodogram from the `KeplerLightCurve` object by using the `periodogram` method.

# %%
pg = lc.to_periodogram(oversample_factor=1)

# %% [markdown]
# Now we can plot the periodogram in the same way that we plot the original light curve.

# %%
pg.plot();

# %% [markdown]
# This looks like there is a huge signal at a certain frequency! Let's plot it in period space, so that we can see what period the oscillation is occurring at.

# %%
pg.plot(view='period', scale='log');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-26d18e75ce0d> in <module>()
# ----> 1 pg.plot(view='period', scale='log');
#
# /opt/anaconda/envs/python3/lib/python3.5/site-packages/lightkurve/periodogram.py in plot(self, scale, ax, xlabel, ylabel, title, style, format, unit, **kwargs)
#     459             # Plot frequency and power
#     460             if format.lower() == 'frequency':
# --> 461                 ax.plot(self.frequency.to(unit), self.power, **kwargs)
#     462                 if xlabel is None:
#     463                     xlabel = "Frequency [{}]".format(unit.to_string('latex'))
#
# /opt/anaconda/envs/python3/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /opt/anaconda/envs/python3/lib/python3.5/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1602         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1603
# -> 1604         for line in self._get_lines(*args, **kwargs):
#    1605             self.add_line(line)
#    1606             lines.append(line)
#
# /opt/anaconda/envs/python3/lib/python3.5/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /opt/anaconda/envs/python3/lib/python3.5/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     381                                   "with non-matching shapes is deprecated.")
#     382         for j in range(max(ncx, ncy)):
# --> 383             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     384             ret.append(seg)
#     385         return ret
#
# /opt/anaconda/envs/python3/lib/python3.5/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     286         default_dict = self._getdefaults(None, kw)
#     287         self._setdefaults(default_dict, kw)
# --> 288         seg = mlines.Line2D(x, y, **kw)
#     289         return seg
#     290
#
# /opt/anaconda/envs/python3/lib/python3.5/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     408         # update kwargs before updating data to give the caller a
#     409         # chance to init axes (and hence unit support)
# --> 410         self.update(kwargs)
#     411         self.pickradius = pickradius
#     412         self.ind_offset = 0
#
# /opt/anaconda/envs/python3/lib/python3.5/site-packages/matplotlib/artist.py in update(self, props)
#     914
#     915         with cbook._setattr_cm(self, eventson=False):
# --> 916             ret = [_update_property(self, k, v) for k, v in props.items()]
#     917
#     918         if len(ret):
#
# /opt/anaconda/envs/python3/lib/python3.5/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     914
#     915         with cbook._setattr_cm(self, eventson=False):
# --> 916             ret = [_update_property(self, k, v) for k, v in props.items()]
#     917
#     918         if len(ret):
#
# /opt/anaconda/envs/python3/lib/python3.5/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     910                 func = getattr(self, 'set_' + k, None)
#     911                 if not callable(func):
# --> 912                     raise AttributeError('Unknown property %s' % k)
#     913                 return func(v)
#     914
#
# AttributeError: Unknown property view

# %% [markdown]
# This looks like a very fast period. Let's find the period with the highest power and fold out light curve.

# %%
period = pg.period_at_max_power
print('Best period: {}'.format(period))
lc.fold(period.value).scatter();
# Out:
# Best period: 0.2587311606278735 d

# %% [markdown]
# As is quite common for eclipsing binaries with deep secondary eclipses, we have found a harmonic of the period of the eclipsing binary. Let's plot it again with quadruple the period.

# %%
period = pg.period_at_max_power * 4
print('Best period: {}'.format(period))
lc.fold(period.value).scatter();
# Out:
# Best period: 1.034924642511494 d

# %% [markdown]
# It looks like we could probably get a better fit than this. Let's try increasing the number of points in our periodogram by increasing the `oversample_factor` parameter.

# %%
# We set the period range below to slightly reduce the computational time
import astropy.units as u
pg = lc.to_periodogram(minimum_period=0.9*u.day, maximum_period=1.2*u.day, oversample_factor=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-27fb744620cc> in <module>()
#       1 # We set the period range below to slightly reduce the computational time
#       2 import astropy.units as u
# ----> 3 pg = lc.to_periodogram(minimum_period=0.9*u.day, maximum_period=1.2*u.day, oversample_factor=10)
#
# /opt/anaconda/envs/python3/lib/python3.5/site-packages/lightkurve/lightcurve.py in to_periodogram(self, nterms, nyquist_factor, oversample_factor, min_frequency, max_frequency, min_period, max_period, frequency, period, freq_unit, **kwargs)
#     958                                            oversample_factor=oversample_factor,
#     959                                            freq_unit=freq_unit,
# --> 960                                            **kwargs)
#     961
#     962     def to_fits(self, path=None, overwrite=False, **extra_data):
#
# /opt/anaconda/envs/python3/lib/python3.5/site-packages/lightkurve/periodogram.py in from_lightcurve(lc, min_frequency, max_frequency, min_period, max_period, frequency, period, nterms, nyquist_factor, oversample_factor, freq_unit, **kwargs)
#     266         if float(__version__[0]) >= 3:
#     267             LS = LombScargle(time, lc.flux * 1e6,
# --> 268                              nterms=nterms, normalization='psd', **kwargs)
#     269             power = LS.power(frequency, method=method)
#     270         else:
#
# TypeError: __init__() got an unexpected keyword argument 'maximum_period'

# %%
period = pg.period_at_max_power
print('Best period: {}'.format(period))
lc.fold(period.value).scatter();
# Out:
# Best period: 1.0350971683913832 d

# %% [markdown]
# This has improved our fit! It looks like this eclipsing binary has a period of approximately 1 day.
